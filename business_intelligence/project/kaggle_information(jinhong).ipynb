# %% [markdown]
# # 필요한 모듈 호출

# %%
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# /home/jinhong/miniconda3/envs/ambiguation/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## 1.데이터 호출

# %%
train_df = pd.read_json("./data/train.json").sort_values(by='listing_id')
test_df = pd.read_json("./data/test.json").sort_values(by='listing_id')

# %% [markdown]
# ## 2.XGB 모델 생성

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=321, num_rounds=3000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.03
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=30)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
test_df["bathrooms"].loc[19671] = 1.5
test_df["bathrooms"].loc[22977] = 2.0
test_df["bathrooms"].loc[63719] = 2.0
train_df["price"] = train_df["price"].clip(upper=13000)

train_df["logprice"] = np.log(train_df["price"])
test_df["logprice"] = np.log(test_df["price"])

train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 

train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

train_df['price_per_room'] = train_df['price']/train_df['room_sum']
test_df['price_per_room'] = test_df['price']/test_df['room_sum']

train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

train_df["created_doy"] = train_df["created"].dt.dayofyear
test_df["created_doy"] = test_df["created"].dt.dayofyear

train_df["pos"] = train_df.longitude.round(3).astype(str) + '_' + train_df.latitude.round(3).astype(str)
test_df["pos"] = test_df.longitude.round(3).astype(str) + '_' + test_df.latitude.round(3).astype(str)

vals = train_df['pos'].value_counts()
dvals = vals.to_dict()
train_df["density"] = train_df['pos'].apply(lambda x: dvals.get(x, vals.min()))
test_df["density"] = test_df['pos'].apply(lambda x: dvals.get(x, vals.min()))

features_to_use=["bathrooms", "bedrooms", "latitude", "longitude", "price","price_t","price_per_room", "logprice", "density",
"num_photos", "num_features", "num_description_words","listing_id", "created_year", "created_month", "created_day", "created_hour","created_doy"]

# %% [markdown]
# ## 3.위도, 경도를 활용하여 feature 생성

# %%
import math
def cart2rho(x, y):
    rho = np.sqrt(x**2 + y**2)
    return rho


def cart2phi(x, y):
    phi = np.arctan2(y, x)
    return phi


def rotation_x(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return x*math.cos(alpha) + y*math.sin(alpha)


def rotation_y(row, alpha):
    x = row['latitude']
    y = row['longitude']
    return y*math.cos(alpha) - x*math.sin(alpha)


def add_rotation(degrees, df):
    namex = "rot" + str(degrees) + "_X"
    namey = "rot" + str(degrees) + "_Y"

    df['num_' + namex] = df.apply(lambda row: rotation_x(row, math.pi/(180/degrees)), axis=1)
    df['num_' + namey] = df.apply(lambda row: rotation_y(row, math.pi/(180/degrees)), axis=1)

    return df

def operate_on_coordinates(tr_df, te_df):
    for df in [tr_df, te_df]:
        #polar coordinates system
        df["num_rho"] = df.apply(lambda x: cart2rho(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        df["num_phi"] = df.apply(lambda x: cart2phi(x["latitude"] - 40.78222222, x["longitude"]+73.96527777), axis=1)
        #rotations
        for angle in [15,30,45,60]:
            df = add_rotation(angle, df)

    return tr_df, te_df

train_df, test_df = operate_on_coordinates(train_df, test_df)

# %%
import s2sphere

lat = train_df.latitude.values.tolist()
lon = train_df.longitude.values.tolist()

cellId1 = []
cellId2 = []
cellId3 = []
for i in range(0,len(lat)):
    p1 = s2sphere.LatLng.from_degrees(lat[i], lon[i])
    cell = s2sphere.CellId.from_lat_lng(p1)
    cid = str(cell.id())
    #print(cid)
    ##cid is a 19 digit number so python storing it as Object, not number
    ##So I am converting it into 3 numbers
    cellId1.append(int(cid[:6]))
    cellId2.append(int(cid[6:12]))
    cellId3.append(int(cid[12:19]))
    

se = pd.Series(cellId1)
train_df['cellId1'] = se.values

se = pd.Series(cellId2)
train_df['cellId2'] = se.values

se = pd.Series(cellId3)
train_df['cellId3'] = se.values

lat = test_df.latitude.values.tolist()
lon = test_df.longitude.values.tolist()

cellId1 = []
cellId2 = []
cellId3 = []
for i in range(0,len(lat)):
    p1 = s2sphere.LatLng.from_degrees(lat[i], lon[i])
    cell = s2sphere.CellId.from_lat_lng(p1)
    cid = str(cell.id())
    #print(cid)
    cellId1.append(int(cid[:6]))
    cellId2.append(int(cid[6:12]))
    cellId3.append(int(cid[12:19]))
    

se = pd.Series(cellId1)
test_df['cellId1'] = se.values

se = pd.Series(cellId2)
test_df['cellId2'] = se.values

se = pd.Series(cellId1)
test_df['cellId3'] = se.values
#selectedFeatures.extend(['cellId1','cellId2','cellId3'])

# %% [markdown]
# ## 4.Description 요소를 정규화하여 Feature 생성
# #### - Description에 대문자 갯수,  줄 수, 수정여부, 이메일 여부, 전화번호가 평가에 영향을 미친다

# %%
import re

def cap_share(x):
    return sum(1 for c in x if c.isupper())/float(len(x)+1)

for df in [train_df, test_df]:
    # do you think that users might feel annoyed BY A DESCRIPTION THAT IS SHOUTING AT THEM?
    df['num_cap_share'] = df['description'].apply(cap_share)
    
    # how long in lines the desc is?
    df['num_nr_of_lines'] = df['description'].apply(lambda x: x.count('<br /><br />'))
   
    # is the description redacted by the website?        
    df['num_redacted'] = 0
    df['num_redacted'].ix[df['description'].str.contains('website_redacted')] = 1

    
    # can we contact someone via e-mail to ask for the details?
    df['num_email'] = 0
    df['num_email'].ix[df['description'].str.contains('@')] = 1
    
    #and... can we call them?
    
    reg = re.compile(".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", re.S)
    def try_and_find_nr(description):
        if reg.match(description) is None:
            return 0
        return 1

    df['num_phone_nr'] = df['description'].apply(try_and_find_nr)
# Out:
# /home/jinhong/miniconda3/envs/ambiguation/lib/python3.5/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# ## 5.생성된 Feature 확인

# %%
train_df.columns
# Out:
# Index(['bathrooms', 'bedrooms', 'building_id', 'created', 'description',
#        'display_address', 'features', 'interest_level', 'latitude',
#        'listing_id', 'longitude', 'manager_id', 'photos', 'price',
#        'street_address', 'logprice', 'price_t', 'room_sum', 'price_per_room',
#        'num_photos', 'num_features', 'num_description_words', 'created_year',
#        'created_month', 'created_day', 'created_hour', 'created_doy', 'pos',
#        'density', 'num_rho', 'num_phi', 'num_rot15_X', 'num_rot15_Y',
#        'num_rot30_X', 'num_rot30_Y', 'num_rot45_X', 'num_rot45_Y',
#        'num_rot60_X', 'num_rot60_Y', 'num_cap_share', 'num_nr_of_lines',
#        'num_redacted', 'num_email', 'num_phone_nr', 'cellId1', 'cellId2',
#        'cellId3'],
#       dtype='object')

# %% [markdown]
# ## 6.생성한 feature 추가

# %%
features_to_use.append("num_rho")
features_to_use.append("num_phi")
features_to_use.append("num_rot15_X")
features_to_use.append("num_rot15_Y")
features_to_use.append("num_rot30_X")
features_to_use.append("num_rot30_Y")
features_to_use.append("num_rot45_X")
features_to_use.append("num_rot45_Y")
features_to_use.append("num_rot60_X")
features_to_use.append("num_rot60_Y")
features_to_use.append("num_cap_share")
features_to_use.append("num_nr_of_lines")
features_to_use.append("num_redacted")
features_to_use.append("num_email")
features_to_use.append("num_phone_nr")
features_to_use.append("cellId1")
features_to_use.append("cellId2")
features_to_use.append("cellId3")

# %% [markdown]
# ## 7.Manager ID로 Feature 생성
# #### - Manager에 대한 평가가 전체적인 평가에 영향을 미친다

# %%
index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

pr=[np.nan]*len(train_df)
for i in range(5):
    building_level={}
    price={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
        price[j]=0
    
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
            price[temp['manager_id']]+=temp['price']

        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
            price[temp['manager_id']]+=temp['price']
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
            price[temp['manager_id']]+=temp['price']
            
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
            pr[j]=price[temp['manager_id']]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c
train_df['avg_price']=pr

a=[]
b=[]
c=[]
pr=[]

building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]
    price[j]=0

for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
        price[temp['manager_id']]+=temp['price']

    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
        price[temp['manager_id']]+=temp['price']

    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1
        price[temp['manager_id']]+=temp['price']


for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
        pr.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
        pr.append(price[i]*1.0/sum(building_level[i]))
        
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c
test_df['avg_price']=pr
features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')
features_to_use.append('avg_price')

categorical = ["display_address", "manager_id", "building_id"]
for f in categorical:
        if train_df[f].dtype=='object':
            lbl = LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))

# %% [markdown]
# ## 8.CountVectorizer로 출몰 빈도수 높은 feature 추출
# #### - 너무 많은 feature를 생성하였기 때문에, feature 수를 줄여줌

# %%
tfidf = CountVectorizer(stop_words='english', max_features=200)
tr_sparse = tfidf.fit_transform(train_df["features"])
te_sparse = tfidf.transform(test_df["features"])

train_X = sparse.hstack([train_df[features_to_use], tr_sparse]).tocsr()
test_X = sparse.hstack([test_df[features_to_use], te_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

# %% [markdown]
# ## 9.모델 학습
# #### - XGB 사용

# %%
from sklearn import model_selection, preprocessing, ensemble

cv_scores = []
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.07798	test-mlogloss:1.07842
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 30 rounds.
# [1]	train-mlogloss:1.05811	test-mlogloss:1.05909
# [2]	train-mlogloss:1.03957	test-mlogloss:1.04102
# [3]	train-mlogloss:1.02245	test-mlogloss:1.02429
# [4]	train-mlogloss:1.00523	test-mlogloss:1.00755
# [5]	train-mlogloss:0.989158	test-mlogloss:0.991879
# [6]	train-mlogloss:0.973429	test-mlogloss:0.976557
# [7]	train-mlogloss:0.958882	test-mlogloss:0.962449
# [8]	train-mlogloss:0.944618	test-mlogloss:0.948532
# [9]	train-mlogloss:0.931016	test-mlogloss:0.935342
# [10]	train-mlogloss:0.918237	test-mlogloss:0.922969
# [11]	train-mlogloss:0.905633	test-mlogloss:0.910835
# [12]	train-mlogloss:0.893453	test-mlogloss:0.899089
# [13]	train-mlogloss:0.881882	test-mlogloss:0.887888
# [14]	train-mlogloss:0.870744	test-mlogloss:0.877097
# [15]	train-mlogloss:0.860179	test-mlogloss:0.866909
# [16]	train-mlogloss:0.85011	test-mlogloss:0.857214
# [17]	train-mlogloss:0.840155	test-mlogloss:0.84764
# [18]	train-mlogloss:0.830702	test-mlogloss:0.838577
# [19]	train-mlogloss:0.821696	test-mlogloss:0.829929
# [20]	train-mlogloss:0.812818	test-mlogloss:0.821447
# [21]	train-mlogloss:0.804342	test-mlogloss:0.813354
# [22]	train-mlogloss:0.796827	test-mlogloss:0.806112
# [23]	train-mlogloss:0.789041	test-mlogloss:0.798765
# [24]	train-mlogloss:0.781657	test-mlogloss:0.791618
# [25]	train-mlogloss:0.774223	test-mlogloss:0.784531
# [26]	train-mlogloss:0.767289	test-mlogloss:0.777849
# [27]	train-mlogloss:0.760364	test-mlogloss:0.771198
# [28]	train-mlogloss:0.753828	test-mlogloss:0.764995
# [29]	train-mlogloss:0.747445	test-mlogloss:0.758865
# [809]	train-mlogloss:0.371309	test-mlogloss:0.516076
# [810]	train-mlogloss:0.371084	test-mlogloss:0.516017
# [811]	train-mlogloss:0.371037	test-mlogloss:0.51601
# [812]	train-mlogloss:0.370921	test-mlogloss:0.515975
# [813]	train-mlogloss:0.370842	test-mlogloss:0.515989
# [814]	train-mlogloss:0.370792	test-mlogloss:0.515974
# [815]	train-mlogloss:0.370674	test-mlogloss:0.515991
# [816]	train-mlogloss:0.370532	test-mlogloss:0.515985
# [817]	train-mlogloss:0.370366	test-mlogloss:0.51594
# [818]	train-mlogloss:0.370136	test-mlogloss:0.515908
# [819]	train-mlogloss:0.370034	test-mlogloss:0.515893
# [820]	train-mlogloss:0.369946	test-mlogloss:0.515875
# [821]	train-mlogloss:0.3698	test-mlogloss:0.515817
# [822]	train-mlogloss:0.369686	test-mlogloss:0.515824
# [823]	train-mlogloss:0.369607	test-mlogloss:0.5158
# [824]	train-mlogloss:0.369597	test-mlogloss:0.515802
# [825]	train-mlogloss:0.369426	test-mlogloss:0.515818
# [826]	train-mlogloss:0.369237	test-mlogloss:0.515822
# [827]	train-mlogloss:0.369036	test-mlogloss:0.515782
# [828]	train-mlogloss:0.368859	test-mlogloss:0.515783
# [829]	train-mlogloss:0.368747	test-mlogloss:0.515778
# [830]	train-mlogloss:0.368609	test-mlogloss:0.515784
# [831]	train-mlogloss:0.368528	test-mlogloss:0.515759
# [832]	train-mlogloss:0.368389	test-mlogloss:0.515753
# [833]	train-mlogloss:0.368271	test-mlogloss:0.515723
# [834]	train-mlogloss:0.368203	test-mlogloss:0.515721
# [835]	train-mlogloss:0.368108	test-mlogloss:0.515698
# [836]	train-mlogloss:0.367988	test-mlogloss:0.515706
# [837]	train-mlogloss:0.36788	test-mlogloss:0.515688
# [838]	train-mlogloss:0.36778	test-mlogloss:0.515686
# [839]	train-mlogloss:0.36768	test-mlogloss:0.515666
# [840]	train-mlogloss:0.367579	test-mlogloss:0.515666
# [841]	train-mlogloss:0.367475	test-mlogloss:0.51567
# [842]	train-mlogloss:0.367368	test-mlogloss:0.515686
# [843]	train-mlogloss:0.367313	test-mlogloss:0.515687
# [844]	train-mlogloss:0.367177	test-mlogloss:0.515671
# [845]	train-mlogloss:0.367001	test-mlogloss:0.515669
# [846]	train-mlogloss:0.366896	test-mlogloss:0.515658
# [847]	train-mlogloss:0.366822	test-mlogloss:0.515652
# [848]	train-mlogloss:0.366741	test-mlogloss:0.515666
# [849]	train-mlogloss:0.366565	test-mlogloss:0.515631
# [850]	train-mlogloss:0.366517	test-mlogloss:0.515649
# [851]	train-mlogloss:0.366367	test-mlogloss:0.515639
# [852]	train-mlogloss:0.366185	test-mlogloss:0.515621
# [853]	train-mlogloss:0.365999	test-mlogloss:0.515601
# [854]	train-mlogloss:0.36587	test-mlogloss:0.515597
# [855]	train-mlogloss:0.365674	test-mlogloss:0.515543
# [856]	train-mlogloss:0.365577	test-mlogloss:0.515512
# [857]	train-mlogloss:0.365516	test-mlogloss:0.515509
# [858]	train-mlogloss:0.365445	test-mlogloss:0.515499
# [859]	train-mlogloss:0.365345	test-mlogloss:0.5155
# [860]	train-mlogloss:0.3653	test-mlogloss:0.515511
# [861]	train-mlogloss:0.365197	test-mlogloss:0.51551
# [862]	train-mlogloss:0.365099	test-mlogloss:0.515527
# [863]	train-mlogloss:0.364909	test-mlogloss:0.515566
# [864]	train-mlogloss:0.364758	test-mlogloss:0.515559
# [865]	train-mlogloss:0.364606	test-mlogloss:0.515556
# [866]	train-mlogloss:0.364543	test-mlogloss:0.515539
# [867]	train-mlogloss:0.364487	test-mlogloss:0.515528
# [868]	train-mlogloss:0.364361	test-mlogloss:0.515528
# [869]	train-mlogloss:0.364181	test-mlogloss:0.515531
# [870]	train-mlogloss:0.364007	test-mlogloss:0.515533
# [871]	train-mlogloss:0.363869	test-mlogloss:0.515529
# [872]	train-mlogloss:0.36369	test-mlogloss:0.515501
# [873]	train-mlogloss:0.363558	test-mlogloss:0.515519
# [874]	train-mlogloss:0.363475	test-mlogloss:0.515517
# [875]	train-mlogloss:0.363312	test-mlogloss:0.51549
# [876]	train-mlogloss:0.36313	test-mlogloss:0.515487
# [877]	train-mlogloss:0.363024	test-mlogloss:0.515486
# [878]	train-mlogloss:0.362965	test-mlogloss:0.515476
# [879]	train-mlogloss:0.362854	test-mlogloss:0.515463
# [880]	train-mlogloss:0.362787	test-mlogloss:0.515475
# [881]	train-mlogloss:0.362691	test-mlogloss:0.515451
# [882]	train-mlogloss:0.362554	test-mlogloss:0.515438
# [883]	train-mlogloss:0.362471	test-mlogloss:0.515434
# [884]	train-mlogloss:0.362425	test-mlogloss:0.515429
# [885]	train-mlogloss:0.362325	test-mlogloss:0.515433
# [886]	train-mlogloss:0.362274	test-mlogloss:0.515424
# [887]	train-mlogloss:0.362102	test-mlogloss:0.515376
# [888]	train-mlogloss:0.361903	test-mlogloss:0.515347
# [889]	train-mlogloss:0.361787	test-mlogloss:0.515342
# [890]	train-mlogloss:0.361717	test-mlogloss:0.515329
# [891]	train-mlogloss:0.361614	test-mlogloss:0.515326
# [892]	train-mlogloss:0.361477	test-mlogloss:0.515263
# [893]	train-mlogloss:0.361411	test-mlogloss:0.51525
# [894]	train-mlogloss:0.361275	test-mlogloss:0.515234
# [895]	train-mlogloss:0.361138	test-mlogloss:0.515182
# [896]	train-mlogloss:0.361122	test-mlogloss:0.515183
# [897]	train-mlogloss:0.361026	test-mlogloss:0.515178
# [898]	train-mlogloss:0.360947	test-mlogloss:0.515177
# [899]	train-mlogloss:0.360858	test-mlogloss:0.51518
# [900]	train-mlogloss:0.360764	test-mlogloss:0.515164
# [901]	train-mlogloss:0.360723	test-mlogloss:0.515157
# [902]	train-mlogloss:0.36064	test-mlogloss:0.515138
# [903]	train-mlogloss:0.360532	test-mlogloss:0.515167
# [904]	train-mlogloss:0.360409	test-mlogloss:0.515193
# [905]	train-mlogloss:0.360287	test-mlogloss:0.515154
# [906]	train-mlogloss:0.360078	test-mlogloss:0.51516
# [907]	train-mlogloss:0.359863	test-mlogloss:0.515155
# [908]	train-mlogloss:0.359758	test-mlogloss:0.515175
# [909]	train-mlogloss:0.359648	test-mlogloss:0.515166
# [910]	train-mlogloss:0.359586	test-mlogloss:0.515168
# [911]	train-mlogloss:0.359413	test-mlogloss:0.515129
# [912]	train-mlogloss:0.359316	test-mlogloss:0.515113
# [913]	train-mlogloss:0.359196	test-mlogloss:0.51511
# [914]	train-mlogloss:0.359064	test-mlogloss:0.515119
# [915]	train-mlogloss:0.35901	test-mlogloss:0.515105
# [916]	train-mlogloss:0.358817	test-mlogloss:0.515081
# [917]	train-mlogloss:0.358761	test-mlogloss:0.515081
# [918]	train-mlogloss:0.358657	test-mlogloss:0.515068
# [919]	train-mlogloss:0.358542	test-mlogloss:0.515056
# [920]	train-mlogloss:0.358358	test-mlogloss:0.515075
# [921]	train-mlogloss:0.358246	test-mlogloss:0.515042
# [922]	train-mlogloss:0.358108	test-mlogloss:0.515062
# [923]	train-mlogloss:0.358016	test-mlogloss:0.515047
# [924]	train-mlogloss:0.357915	test-mlogloss:0.515043
# [925]	train-mlogloss:0.357796	test-mlogloss:0.515051
# [926]	train-mlogloss:0.35774	test-mlogloss:0.515068
# [927]	train-mlogloss:0.357662	test-mlogloss:0.515054
# [928]	train-mlogloss:0.357565	test-mlogloss:0.515031
# [929]	train-mlogloss:0.357481	test-mlogloss:0.515033
# [930]	train-mlogloss:0.357283	test-mlogloss:0.515048
# [931]	train-mlogloss:0.357212	test-mlogloss:0.51505
# [932]	train-mlogloss:0.357135	test-mlogloss:0.515051
# [933]	train-mlogloss:0.357082	test-mlogloss:0.515054
# [934]	train-mlogloss:0.357027	test-mlogloss:0.51505
# [935]	train-mlogloss:0.356865	test-mlogloss:0.515073
# [936]	train-mlogloss:0.356708	test-mlogloss:0.515067
# [937]	train-mlogloss:0.356648	test-mlogloss:0.515069
# [938]	train-mlogloss:0.356518	test-mlogloss:0.515061
# [939]	train-mlogloss:0.35641	test-mlogloss:0.515078
# [940]	train-mlogloss:0.356317	test-mlogloss:0.515064
# [941]	train-mlogloss:0.356223	test-mlogloss:0.515044
# [942]	train-mlogloss:0.356177	test-mlogloss:0.515026
# [943]	train-mlogloss:0.356168	test-mlogloss:0.515019
# [944]	train-mlogloss:0.356072	test-mlogloss:0.514997
# [945]	train-mlogloss:0.35585	test-mlogloss:0.515003
# [946]	train-mlogloss:0.355713	test-mlogloss:0.514998
# [947]	train-mlogloss:0.355628	test-mlogloss:0.514996
# [948]	train-mlogloss:0.355537	test-mlogloss:0.515013
# [949]	train-mlogloss:0.355361	test-mlogloss:0.515017
# [950]	train-mlogloss:0.355239	test-mlogloss:0.514993
# [951]	train-mlogloss:0.355132	test-mlogloss:0.514984
# [952]	train-mlogloss:0.355074	test-mlogloss:0.514974
# [953]	train-mlogloss:0.354968	test-mlogloss:0.514973
# [954]	train-mlogloss:0.35475	test-mlogloss:0.51496
# [955]	train-mlogloss:0.354591	test-mlogloss:0.514989
# [956]	train-mlogloss:0.354517	test-mlogloss:0.514976
# [957]	train-mlogloss:0.354425	test-mlogloss:0.514964
# [958]	train-mlogloss:0.354315	test-mlogloss:0.514965
# [959]	train-mlogloss:0.354244	test-mlogloss:0.514953
# [960]	train-mlogloss:0.354114	test-mlogloss:0.514938
# [961]	train-mlogloss:0.353955	test-mlogloss:0.514885
# [962]	train-mlogloss:0.353773	test-mlogloss:0.514851
# [963]	train-mlogloss:0.353628	test-mlogloss:0.514857
# [964]	train-mlogloss:0.353503	test-mlogloss:0.514816
# [965]	train-mlogloss:0.353429	test-mlogloss:0.514832
# [966]	train-mlogloss:0.353337	test-mlogloss:0.514845
# [967]	train-mlogloss:0.353241	test-mlogloss:0.514833
# [968]	train-mlogloss:0.353167	test-mlogloss:0.514829
# [969]	train-mlogloss:0.353051	test-mlogloss:0.514826
# [970]	train-mlogloss:0.352996	test-mlogloss:0.514828
# [971]	train-mlogloss:0.352873	test-mlogloss:0.51484
# [972]	train-mlogloss:0.352707	test-mlogloss:0.514817
# [973]	train-mlogloss:0.352544	test-mlogloss:0.514839
# [974]	train-mlogloss:0.352497	test-mlogloss:0.514848
# [975]	train-mlogloss:0.352399	test-mlogloss:0.51487
# [976]	train-mlogloss:0.352336	test-mlogloss:0.514838
# [977]	train-mlogloss:0.35222	test-mlogloss:0.514808
# [978]	train-mlogloss:0.352029	test-mlogloss:0.514772
# [979]	train-mlogloss:0.351859	test-mlogloss:0.514751
# [980]	train-mlogloss:0.351682	test-mlogloss:0.514711
# [981]	train-mlogloss:0.351584	test-mlogloss:0.514696
# [982]	train-mlogloss:0.351449	test-mlogloss:0.514672
# [983]	train-mlogloss:0.351317	test-mlogloss:0.514674
# [984]	train-mlogloss:0.351208	test-mlogloss:0.514659
# [985]	train-mlogloss:0.351169	test-mlogloss:0.514653
# [986]	train-mlogloss:0.351044	test-mlogloss:0.514617
# [987]	train-mlogloss:0.350934	test-mlogloss:0.514596
# [988]	train-mlogloss:0.350879	test-mlogloss:0.514594
# [989]	train-mlogloss:0.350783	test-mlogloss:0.514616
# [990]	train-mlogloss:0.350658	test-mlogloss:0.514583
# [991]	train-mlogloss:0.350565	test-mlogloss:0.514564
# [992]	train-mlogloss:0.350403	test-mlogloss:0.514563
# [993]	train-mlogloss:0.350299	test-mlogloss:0.514521
# [994]	train-mlogloss:0.350174	test-mlogloss:0.51454
# [995]	train-mlogloss:0.350069	test-mlogloss:0.514501
# [996]	train-mlogloss:0.349847	test-mlogloss:0.514453
# [997]	train-mlogloss:0.349643	test-mlogloss:0.514431
# [998]	train-mlogloss:0.349505	test-mlogloss:0.514424
# [999]	train-mlogloss:0.349418	test-mlogloss:0.514414
# [1000]	train-mlogloss:0.349308	test-mlogloss:0.514405
# [1001]	train-mlogloss:0.349236	test-mlogloss:0.514404
# [1002]	train-mlogloss:0.349116	test-mlogloss:0.514382
# [1003]	train-mlogloss:0.349002	test-mlogloss:0.514351
# [1051]	train-mlogloss:0.343401	test-mlogloss:0.514061
# [1052]	train-mlogloss:0.343255	test-mlogloss:0.51403
# [1053]	train-mlogloss:0.34309	test-mlogloss:0.514025
# [1054]	train-mlogloss:0.342971	test-mlogloss:0.514047
# [1055]	train-mlogloss:0.34289	test-mlogloss:0.514045
# [1056]	train-mlogloss:0.342808	test-mlogloss:0.514033
# [1057]	train-mlogloss:0.342638	test-mlogloss:0.514033
# [1058]	train-mlogloss:0.342586	test-mlogloss:0.514047
# [1059]	train-mlogloss:0.342489	test-mlogloss:0.514039
# [1060]	train-mlogloss:0.342346	test-mlogloss:0.51403
# [1061]	train-mlogloss:0.342152	test-mlogloss:0.514058
# [1062]	train-mlogloss:0.342027	test-mlogloss:0.514051
# [1063]	train-mlogloss:0.341866	test-mlogloss:0.514029
# [1064]	train-mlogloss:0.341647	test-mlogloss:0.514034
# [1065]	train-mlogloss:0.34158	test-mlogloss:0.514056
# [1066]	train-mlogloss:0.341413	test-mlogloss:0.514094
# [1067]	train-mlogloss:0.341341	test-mlogloss:0.514112
# [1068]	train-mlogloss:0.341288	test-mlogloss:0.5141
# [1069]	train-mlogloss:0.341236	test-mlogloss:0.514103
# [1070]	train-mlogloss:0.341076	test-mlogloss:0.514101
# [1071]	train-mlogloss:0.340989	test-mlogloss:0.514092
# [1072]	train-mlogloss:0.340956	test-mlogloss:0.514081
# [1073]	train-mlogloss:0.340825	test-mlogloss:0.514106
# [1074]	train-mlogloss:0.340744	test-mlogloss:0.514101
# [1075]	train-mlogloss:0.340647	test-mlogloss:0.514093
# [1076]	train-mlogloss:0.340569	test-mlogloss:0.514112
# [1077]	train-mlogloss:0.340427	test-mlogloss:0.514081
# [1078]	train-mlogloss:0.340341	test-mlogloss:0.514118
# [1079]	train-mlogloss:0.340186	test-mlogloss:0.51414
# [1080]	train-mlogloss:0.340057	test-mlogloss:0.514146
# [1081]	train-mlogloss:0.339957	test-mlogloss:0.514153
# [1082]	train-mlogloss:0.33989	test-mlogloss:0.514145
# [1083]	train-mlogloss:0.339793	test-mlogloss:0.514164
# Stopping. Best iteration:
# [1053]	train-mlogloss:0.34309	test-mlogloss:0.514025
#
# [0.51416440414726794]

# %% [markdown]
# ## 성능 평가

# %%
from sklearn.metrics import classification_report

pred_y = np.array([np.argmax(i) for i in preds])
pred_y, y = pd.Series(pred_y), pd.Series(val_y)

print(classification_report(y, pred_y))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.60      0.37      0.46       747
#           1       0.54      0.43      0.48      2319
#           2       0.83      0.92      0.87      6805
#
# avg / total       0.74      0.76      0.75      9871

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1550)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("0.53208_7.csv", index=False)

# %% [markdown]
# ## 제출 결과 0.52952 나옴

# %% [markdown]
# <img width="800px" height="500px" src="https://github.com/jinongkim/pycon_image_data/blob/master/0.52952.png?raw=true"></img>
