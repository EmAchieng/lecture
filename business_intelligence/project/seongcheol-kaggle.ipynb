# %% [markdown]
# ## 모듈호출

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import  linear_model
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# ## 데이터 호출

# %%
train_df = pd.read_json('./input/train.json')
test_df = pd.read_json('./input/test.json')

# %%
train_df.head().T
# Out:
#                                                             10      \
# bathrooms                                                      1.5
# bedrooms                                                         3
# building_id                       53a5b119ba8f7b61d4e010512e0dfc85
# created                                        2016-06-24 07:54:24
# description      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# display_address                                Metropolitan Avenue
# features                                                        []
# interest_level                                              medium
# latitude                                                   40.7145
# listing_id                                                 7211212
# longitude                                                 -73.9425
# manager_id                        5ba989232d0489da1b5f2c45f6688adc
# photos           [https://photos.renthop.com/2/7211212_1ed4542e...
# price                                                         3000
# street_address                             792 Metropolitan Avenue
#
#                                                             10000   \
# bathrooms                                                        1
# bedrooms                                                         2
# building_id                       c5c8a357cba207596b04d1afd1e4f130
# created                                        2016-06-12 12:19:27
# description
# display_address                                    Columbus Avenue
# features         [Doorman, Elevator, Fitness Center, Cats Allow...
# interest_level                                                 low
# latitude                                                   40.7947
# listing_id                                                 7150865
# longitude                                                 -73.9667
# manager_id                        7533621a882f71e25173b27e3139d83d
# photos           [https://photos.renthop.com/2/7150865_be3306c5...
# price                                                         5465
# street_address                                 808 Columbus Avenue
#
#                                                             100004  \
# bathrooms                                                        1
# bedrooms                                                         1
# building_id                       c3ba40552e2120b0acfc3cb5730bb2aa
# created                                        2016-04-17 03:26:41
# description      Top Top West Village location, beautiful Pre-w...
# display_address                                        W 13 Street
# features         [Laundry In Building, Dishwasher, Hardwood Flo...
# interest_level                                                high
# latitude                                                   40.7388
# listing_id                                                 6887163
# longitude                                                 -74.0018
# manager_id                        d9039c43983f6e564b1482b273bd7b01
# photos           [https://photos.renthop.com/2/6887163_de85c427...
# price                                                         2850
# street_address                                     241 W 13 Street
#
#                                                             100007  \
# bathrooms                                                        1
# bedrooms                                                         1
# building_id                       28d9ad350afeaab8027513a3e52ac8d5
# created                                        2016-04-18 02:22:02
# description      Building Amenities - Garage - Garden - fitness...
# display_address                                   East 49th Street
# features                                 [Hardwood Floors, No Fee]
# interest_level                                                 low
# latitude                                                   40.7539
# listing_id                                                 6888711
# longitude                                                 -73.9677
# manager_id                        1067e078446a7897d2da493d2f741316
# photos           [https://photos.renthop.com/2/6888711_6e660cee...
# price                                                         3275
# street_address                                333 East 49th Street
#
#                                                             100013
# bathrooms                                                        1
# bedrooms                                                         4
# building_id                                                      0
# created                                        2016-04-28 01:32:41
# description      Beautifully renovated 3 bedroom flex 4 bedroom...
# display_address                                  West 143rd Street
# features                                                 [Pre-War]
# interest_level                                                 low
# latitude                                                   40.8241
# listing_id                                                 6934781
# longitude                                                 -73.9493
# manager_id                        98e13ad4b495b9613cef886d79a6291f
# photos           [https://photos.renthop.com/2/6934781_1fa4b41a...
# price                                                         3350
# street_address                               500 West 143rd Street

# %%
train_df.shape
# Out:
# (49352, 15)

# %% [markdown]
# ## Feature 추가 1
# - num_photos
# - num_features
# - num_description_words
# - created
# - created_year
# - created_month
# - created_day

# %%
a = train_df["display_address"].tolist()
address = list(set(a))

# %%
val_address = []
for i in address:
    if a.count(i)>= 10:
        val_address.append(i)

val_address = val_address[1:]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

# %%
train_df["val_address"] = train_df["display_address"].apply(lambda x: 1 if x in val_address else 0)
test_df["val_address"] = test_df["display_address"].apply(lambda x: 1 if x in val_address else 0)

# %%
for col in ['display_address', 'street_address', 'building_id']:
        train_df[col] = LabelEncoder().fit_transform(train_df[col])
        test_df[col] = LabelEncoder().fit_transform(test_df[col])

# %%
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year

train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month

train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day

# train_df["sum_bb"] = train_df["bedrooms"]+train_df["bathrooms"]
# test_df["sum_bb"] = test_df["bedrooms"]+test_df["bathrooms"]

# train_df['price_per_bed'] = train_df['price'] / (train_df['bedrooms'] + 1)
# test_df['price_per_bed'] = test_df['price'] / (test_df['bedrooms'] + 1)

# train_df['price_per_bath'] = train_df['price'] / (train_df['bathrooms'] + 1)
# test_df['price_per_bath'] = test_df['price'] / (test_df['bathrooms'] + 1)

# train_df['price_per_room'] = train_df['price'] / (train_df['bathrooms'] * 0.5 + train_df['bedrooms'] + 1)
# test_df['price_per_room'] = test_df['price'] / (test_df['bathrooms'] * 0.5 + test_df['bedrooms'] + 1)



use_feats = ["bathrooms", "bedrooms", "latitude", "longitude", "price",
             "num_photos", "num_features", "num_description_words",
             "created_year", "created_month", 'street_address', 'building_id']

# X = train_df[use_feats]
# test_X = test_df[use_feats]

# y = train_df["interest_level"]

# X_train2, X_val, y_train2, y_val = train_test_split(X, y, test_size=0.3)

# %%
X_train = train_df
X_test = test_df

# %% [markdown]
# ## Feature 추가 2
# - 위도와 경도 클러스터링

# %%
from sklearn.cluster import KMeans

X_train['response'] = 0.
X_train.loc[X_train.interest_level=='medium', 'response'] = 0.5
X_train.loc[X_train.interest_level=='high', 'response'] = 1

print('Length before removing ouliers', len(X_train))
for i in ['latitude', 'longitude']:
    while(1):
        x = X_train[i].median()
        ix = abs(X_train[i] - x) > 3*X_train[i].std()
        if ix.sum()==0: # no more outliers -> stop
            break
        X_train.loc[ix, i] = np.nan # exclude outliers
# Keep only non-outlier listings
X_train = X_train.loc[X_train[['latitude', 'longitude']].isnull().sum(1) == 0, :]
print('Length after removing ouliers', len(X_train))

ncomp = [5,10,20,40]
r = KMeans(ncomp[1], random_state=5)
    # Normalize (longitude, latitude) before K-means
temp = X_train[['longitude', 'latitude']].copy()
temp['longitude'] = (temp['longitude']-temp['longitude'].mean())/temp['longitude'].std()
temp['latitude'] = (temp['latitude']-temp['latitude'].mean())/temp['latitude'].std()
    # Fit k-means and get labels
r.fit(temp[['longitude', 'latitude']])
X_train['labels'] = r.labels_

r.fit(X_test[['longitude', 'latitude']])
X_test['labels'] = r.labels_

use_feats.append('labels')
# Out:
# Length before removing ouliers 49352
# Length after removing ouliers 46946
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Feature 추가 3
# - Elevator의 수
# - 애완동물의 허용여부를 이용한 동물친화도 추가

# %%
def newfeat(name, df, series):
    """Create a Series for my feature building loop to fill"""
    feature = pd.Series(0, df.index, name=name)
    """Now populate the new Series with numeric values"""
    for row, word in enumerate(series):
        if name in word:
            feature.iloc[row] = 1
    df[name] = feature
    return(df)
   
X_train = newfeat('Elevator', X_train, X_train.features)
X_train = newfeat('Dogs Allowed', X_train, X_train.features)
X_train = newfeat('Cats Allowed', X_train, X_train.features)
X_train['pet_friendly'] = X_train['Cats Allowed'] + X_train['Dogs Allowed']

X_test = newfeat('Elevator', X_test, X_test.features)
X_test = newfeat('Dogs Allowed', X_test, X_test.features)
X_test = newfeat('Cats Allowed', X_test, X_test.features)
X_test['pet_friendly'] = X_test['Cats Allowed'] + X_test['Dogs Allowed']
# Out:
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Feature 추가 4
# - Manager의 평가도를 'high', 'medium', 'low'로 구분

# %%
import random

index=list(range(X_train.shape[0]))
random.shuffle(index)
a=[np.nan]*len(X_train)
b=[np.nan]*len(X_train)
c=[np.nan]*len(X_train)

for i in range(5):
    building_level={}
    for j in X_train['manager_id'].values:
        building_level[j]=[0,0,0]
    test_index=index[int((i*X_train.shape[0])/5):int(((i+1)*X_train.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=X_train.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=X_train.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
X_train['manager_level_low']=a
X_train['manager_level_medium']=b
X_train['manager_level_high']=c

a=[]
b=[]
c=[]
building_level={}
for j in X_train['manager_id'].values:
    building_level[j]=[0,0,0]
for j in range(X_train.shape[0]):
    temp=X_train.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in X_test['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))

X_test['manager_level_low']=a
X_test['manager_level_medium']=b
X_test['manager_level_high']=c
# Out:
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\ipykernel\__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### nan값을 0으로 변환

# %%
X_train[['manager_level_low', 'manager_level_medium', 'manager_level_high']] = X_train[['manager_level_low', 'manager_level_medium', 'manager_level_high']].astype(np.float32)
X_test[['manager_level_low', 'manager_level_medium', 'manager_level_high']] = X_test[['manager_level_low', 'manager_level_medium', 'manager_level_high']].astype(np.float32)

X_train[['manager_level_low', 'manager_level_medium', 'manager_level_high']] = X_train[['manager_level_low', 'manager_level_medium', 'manager_level_high']].replace(np.nan, 0.0, regex=True)
X_test[['manager_level_low', 'manager_level_medium', 'manager_level_high']] = X_test[['manager_level_low', 'manager_level_medium', 'manager_level_high']].replace(np.nan, 0.0, regex=True)
# Out:
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\pandas\core\frame.py:2440: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
use_feats.append('manager_level_low') 
use_feats.append('manager_level_medium') 
use_feats.append('manager_level_high')

# %% [markdown]
# ## XGBoost 사용

# %%
from scipy import sparse
import xgboost as xgb
import random
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(X_train['interest_level'].apply(lambda x: target_num_map[x]))

train_test = sparse.coo_matrix(X_train[use_feats]).tocsr()
test_test = sparse.coo_matrix(X_test[use_feats]).tocsr()

def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=2000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.03
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model
# Out:
# C:\Users\USER\Miniconda3\envs\coursera\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.metrics import classification_report

# %%
cv_scores = []
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_test.shape[0])):
        dev_X, val_X = train_test[dev_index,:], train_test[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
#         print(classification_report(val_y, preds))
        break

preds, model = runXGB(train_test, train_y, test_test, num_rounds=2000)
# Out:
# [0]	train-mlogloss:1.07834	test-mlogloss:1.07868
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.05905	test-mlogloss:1.05975
# [2]	train-mlogloss:1.04016	test-mlogloss:1.04128
# [3]	train-mlogloss:1.02282	test-mlogloss:1.02422
# [4]	train-mlogloss:1.00584	test-mlogloss:1.00759
# [5]	train-mlogloss:0.989473	test-mlogloss:0.991544
# [6]	train-mlogloss:0.973887	test-mlogloss:0.976212
# [7]	train-mlogloss:0.959206	test-mlogloss:0.961811
# [8]	train-mlogloss:0.944977	test-mlogloss:0.947883
# [9]	train-mlogloss:0.931314	test-mlogloss:0.934599
# [10]	train-mlogloss:0.918418	test-mlogloss:0.921954
# [11]	train-mlogloss:0.906095	test-mlogloss:0.909942
# [12]	train-mlogloss:0.894795	test-mlogloss:0.898852
# [13]	train-mlogloss:0.883052	test-mlogloss:0.887398
# [14]	train-mlogloss:0.872262	test-mlogloss:0.876842
# [15]	train-mlogloss:0.861616	test-mlogloss:0.866465
# [16]	train-mlogloss:0.851725	test-mlogloss:0.856835
# [17]	train-mlogloss:0.841789	test-mlogloss:0.847203
# [18]	train-mlogloss:0.832749	test-mlogloss:0.838417
# [19]	train-mlogloss:0.823869	test-mlogloss:0.829836
# [20]	train-mlogloss:0.815198	test-mlogloss:0.821409
# [21]	train-mlogloss:0.807088	test-mlogloss:0.813568
# [22]	train-mlogloss:0.799206	test-mlogloss:0.805935
# [23]	train-mlogloss:0.791527	test-mlogloss:0.798559
# [24]	train-mlogloss:0.784234	test-mlogloss:0.791568
# [25]	train-mlogloss:0.777245	test-mlogloss:0.784777
# [26]	train-mlogloss:0.770288	test-mlogloss:0.778132
# [27]	train-mlogloss:0.763583	test-mlogloss:0.771816
# [28]	train-mlogloss:0.757068	test-mlogloss:0.765532
# [29]	train-mlogloss:0.750858	test-mlogloss:0.759557
# [30]	train-mlogloss:0.744785	test-mlogloss:0.753784
# [31]	train-mlogloss:0.738982	test-mlogloss:0.748244
# [32]	train-mlogloss:0.733364	test-mlogloss:0.74293
# [33]	train-mlogloss:0.727912	test-mlogloss:0.737725
# [624]	train-mlogloss:0.414447	test-mlogloss:0.541898
# [625]	train-mlogloss:0.414275	test-mlogloss:0.541861
# [626]	train-mlogloss:0.414099	test-mlogloss:0.541801
# [627]	train-mlogloss:0.413999	test-mlogloss:0.541812
# [628]	train-mlogloss:0.413847	test-mlogloss:0.541793
# [629]	train-mlogloss:0.41367	test-mlogloss:0.541744
# [630]	train-mlogloss:0.413522	test-mlogloss:0.541727
# [631]	train-mlogloss:0.413365	test-mlogloss:0.541702
# [632]	train-mlogloss:0.413195	test-mlogloss:0.541669
# [633]	train-mlogloss:0.413021	test-mlogloss:0.541645
# [634]	train-mlogloss:0.412818	test-mlogloss:0.541668
# [635]	train-mlogloss:0.412655	test-mlogloss:0.54166
# [636]	train-mlogloss:0.412531	test-mlogloss:0.541643
# [637]	train-mlogloss:0.412378	test-mlogloss:0.541645
# [638]	train-mlogloss:0.412212	test-mlogloss:0.541611
# [639]	train-mlogloss:0.412016	test-mlogloss:0.541625
# [640]	train-mlogloss:0.411863	test-mlogloss:0.541627
# [641]	train-mlogloss:0.411651	test-mlogloss:0.541567
# [642]	train-mlogloss:0.411481	test-mlogloss:0.541544
# [643]	train-mlogloss:0.411314	test-mlogloss:0.541523
# [644]	train-mlogloss:0.411089	test-mlogloss:0.54151
# [645]	train-mlogloss:0.41096	test-mlogloss:0.54152
# [646]	train-mlogloss:0.410757	test-mlogloss:0.541533
# [647]	train-mlogloss:0.410616	test-mlogloss:0.541538
# [648]	train-mlogloss:0.410472	test-mlogloss:0.541569
# [649]	train-mlogloss:0.410263	test-mlogloss:0.541568
# [650]	train-mlogloss:0.410079	test-mlogloss:0.54156
# [651]	train-mlogloss:0.409875	test-mlogloss:0.541577
# [652]	train-mlogloss:0.409718	test-mlogloss:0.541595
# [653]	train-mlogloss:0.409563	test-mlogloss:0.541631
# [654]	train-mlogloss:0.40938	test-mlogloss:0.54159
# [655]	train-mlogloss:0.409222	test-mlogloss:0.541583
# [656]	train-mlogloss:0.409075	test-mlogloss:0.541589
# [657]	train-mlogloss:0.408893	test-mlogloss:0.541571
# [658]	train-mlogloss:0.408739	test-mlogloss:0.541572
# [659]	train-mlogloss:0.408616	test-mlogloss:0.541558
# [660]	train-mlogloss:0.408495	test-mlogloss:0.541567
# [661]	train-mlogloss:0.408301	test-mlogloss:0.541549
# [662]	train-mlogloss:0.408117	test-mlogloss:0.541574
# [663]	train-mlogloss:0.407966	test-mlogloss:0.541547
# [664]	train-mlogloss:0.407789	test-mlogloss:0.541568
# Stopping. Best iteration:
# [644]	train-mlogloss:0.411089	test-mlogloss:0.54151
#
# [0.54156768584907966]

# %% [markdown]
# - train-mlogloss: 0.411089
# - test-mlogloss: 0.54151
# - score: 0.58041
# ![](https://github.com/SeongCheol-Kim/quiz_pic/blob/master/K-MOOC%20OR/kaggle_result.png?raw=true)

# %%
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = X_test.listing_id.values

out_df.to_csv("result_6.csv", index=False)
